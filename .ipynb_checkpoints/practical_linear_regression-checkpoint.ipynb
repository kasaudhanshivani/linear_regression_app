# %%
import pandas as pd ##structured data
import matplotlib.pyplot as plt ##visualisation
import numpy as np ##numerical data
# %matplotlib inline

# %%
df=pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
df.shape
# Out:
# (23, 2)

# %%
##scatter plot 
plt.scatter(df['Height'],df['Weight'])
plt.xlabel("Weight")
plt.ylabel("Height")
plt.title("Height vs Weight")
plt.show()

# %%
##corealtion
 ##Scatter plot with regression line
plt.figure(figsize=(8,6))
sns.regplot(x='Height', y='Weight', data=df, scatter_kws={'color':'blue'}, line_kws={'color':'red'})

plt.xlabel("Height")

df.corr()
plt.figure(figsize=(6,5))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
##seaborn
import seaborn as sns
sns.pairplot(df)

# %%
##independent feature and dependent
X = df['Weight']#indedpendent#np.array(X)
Y = df['Height']

# %%
X = df[['Weight']]   # double brackets → DataFrame should be 2d or data frame
Y = df['Height']     # target can be Series-in 1d output

# %% [markdown]
# ML models expect X as a matrix (n × features).
#
# df['Weight'] → 1D (Series)
#
# df[['Weight']] → 2D (DataFrame)

# %%
df['Weight'].shape     # (n,)
# Out:
# (23,)

# %%
df[['Weight']].shape   # (n, 1)
# Out:
# (23, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.25, random_state=42
)

# %%
X_train.shape
# Out:
# (17, 1)

# %%
##standardization
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.33497168],
#        [ 0.33497168],
#        [-1.6641678 ],
#        [ 1.36483141],
#        [-0.45256812],
#        [ 1.97063125]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
regression.coef_
# Out:
# array([17.2982057])

# %%
print("coeffiecent or slope",regression.coef_)
print("intercept",regression.intercept_)
# Out:
# coeffiecent or slope [17.2982057]
# intercept 156.47058823529412

# %%
##plt traing data and plot best fit line
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# %% [markdown]
# Prediction of test data
# 1 predicted height _output = intercept+coeff(weights)
# 2 y_pred=regression.predict(X_test)

# %%
y_predict=regression.predict(X_test)

# %%
##performance 
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 mse=mean_squared_error(y_test,y_pred)
#       2 mae=mean_absolute_error(y_test,y_pred)
#       3 rmse=np.sqrt(mse)
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# R² Formula
# 𝑅
# 2
# =
# 1
# −
# 𝑆
# 𝑆
# 𝑟
# 𝑒
# 𝑠
# 𝑆
# 𝑆
# 𝑡
# 𝑜
# 𝑡
# R
# 2
# =1−
# SS
# tot
# 	​
#
# SS
# res
# 	​
#
# 	​

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)

# %% [markdown]
# Adjusted R² Formula
# Adjusted
# 𝑅
# 2
# =
# 1
# −
# (
# 1
# −
# 𝑅
# 2
# )
# 𝑛
# −
# 1
# 𝑛
# −
# 𝑝
# −
# 1
# Adjusted R
# 2
# =1−(1−R
# 2
# )
# n−p−1
# n−1
# 	​

# %%
score = r2_score(y_test, y_pred)   # normal R²

n = len(y_test)
p = X_test.shape[1]

adjusted_r2 = 1 - (1 - score) * (n - 1) / (n - p - 1)

print("Adjusted R²:", adjusted_r2)

# %% [markdown]
# ols

# %%
# !pip install --upgrade statsmodels

# %%
import statsmodels.api as sm

# %% [markdown]
# models=sm.DLS(y_train,X_train).fit()

# %%
models=sm.OLS(y_train,X_train).fit()

# %%
pd=models.predict(X_test)
print(pd)

# %%
print(models.summary())

# %%
##prediction for new data

# %%
regression.predict(scaler.transform([[72]]))

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
import pandas as pd

# New weights you want to predict height for
new_data = pd.DataFrame({'Weight': [40, 55, 70, 82, 95]})

# Predict using sklearn model
pred_sklearn = lr.predict(new_data)
pred_sklearn

# %%
X_ols = sm.add_constant(X)
model = sm.OLS(y, X_ols).fit()

# %%
# Add constant column for OLS
new_data_ols = sm.add_constant(new_data)

# Predict using OLS model
pred_ols = model.predict(new_data_ols)
pred_ols
