# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
df= pd.read_csv("economic_index.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %%
df.drop(columns=["Unnamed: 0","year","month"],axis=1,inplace =True)

# %%
df.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
df.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.pairplot(df)
plt.show()

# %%
df.corr()

plt.figure(figsize=(6,5))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.scatter(df['interest_rate'],df['unemployment_rate'],color='r')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x='interest_rate', y='unemployment_rate', data=df, scatter_kws={'color':'blue'}, line_kws={'color':'red'})
plt.xlabel("Interest Rate")
plt.ylabel("Unemployment Rate")
plt.title("Interest Rate vs Unemployment Rate with Regression Line")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x='interest_rate', y='index_price', data=df, scatter_kws={'color':'blue'}, line_kws={'color':'red'})
plt.xlabel("Interest Rate")
plt.ylabel("Unemployment Rate")
plt.title("Interest Rate vs Unemployment Rate with Regression Line")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.25, random_state=42
)

X_train.shape
# Out:
# (18, 2)

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


# 4. Features and target
X = df[['interest_rate', 'unemployment_rate']]  # multiple features
Y = df['index_price']                            # target

# 5. Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# 6. Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# 7. Linear Regression
model = LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %% [raw]
# from sklearn.model_selection import cross_val_score
#
# regression = LinearRegression()
#
# # Perform 5-fold cross-validation
# validation_score = cross_val_score(
#     regression,       # the model
#     X_train_scaled,   # features (scaled training data)
#     y_train,          # target
#     cv=3,             # number of folds
#     scoring='neg_mean_squared_error'      # metric; can be 'r2', 'neg_mean_squared_error', etc.
# )
# mse_scores = -validation_score
# print("MSE for each fold:", mse_scores)
# print("Average MSE:", mse_scores.mean())

# %%
y_predict=regression.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 y_predict=regression.predict(X_test)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_base.py:275, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
# --> 275     check_is_fitted(self)
#     277     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     278     coef_ = self.coef_
#
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 mse=mean_squared_error(y_test,y_pred)
#       2 mae=mean_absolute_error(y_test,y_pred)
#       3 rmse=np.sqrt(mse)
#
# NameError: name 'y_pred' is not defined

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 model.summary()
#
# AttributeError: 'LinearRegression' object has no attribute 'summary'

# %%
# !pip install --upgrade statsmodels

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 model.summary()
#
# AttributeError: 'LinearRegression' object has no attribute 'summary'
